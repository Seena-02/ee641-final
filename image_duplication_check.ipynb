# %%
# !python ./generate_dataset.py --size=5 --variations=100
# Out:
# Generated 70 unique solution patterns
#
# ============================================================
# DATASET SPLIT
# ============================================================
# Total unique solution patterns: 70
# Train solution patterns: 56
# Test solution patterns: 14
# Variations per solution: 100
# Total train images: 5600
# Total test images: 1400
# ============================================================
#
# Generating TRAIN set...
# Generating TEST set...
#
# ✓ Saved 5600 train examples to data/train_sequences.json
# ✓ Saved 1400 test examples to data/test_sequences.json
# ✓ Metadata included: {'grid_size': 5, 'rows': 5, 'cols': 5, 'seed': 69, 'variations': 100, 'train_split': 0.8, 'start_position': [0, 4], 'goal_position': [4, 0]}
#
# ============================================================
# ✓ Dataset generation complete!
# ============================================================
# Train images: data/grids/train/
# Test images: data/grids/test/
# Train JSON: data/train_sequences.json
# Test JSON: data/test_sequences.json
#
# 🔍 CHECK: Open a few train images with same solution_id
#    They should have DIFFERENT wall patterns!
# ============================================================

# %%
import os
from PIL import Image
import imagehash
from collections import defaultdict

# ---- CONFIG ----
image_folder = "data/grids/both"   # << CHANGE THIS
valid_ext = {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff"}

# ---- STEP 1: Compute image hashes ----
hash_dict = defaultdict(list)

for filename in os.listdir(image_folder):
    ext = os.path.splitext(filename)[1].lower()
    if ext not in valid_ext:
        continue  # skip non-images

    filepath = os.path.join(image_folder, filename)

    try:
        img = Image.open(filepath)
        img_hash = imagehash.phash(img)  # perceptual hash
        hash_dict[str(img_hash)].append(filename)
    except Exception as e:
        print(f"Error reading {filename}: {e}")

# ---- STEP 2: Print duplicates ----
duplicates = {h: files for h, files in hash_dict.items() if len(files) > 1}

if duplicates:
    print("🔍 Found duplicate images (visually identical):\n")
    for h, files in duplicates.items():
        print(f"Hash: {h}")
        for f in files:
            print(f"  - {f}")
        print()
else:
    print("✅ No duplicate images found.")
# Out:
# 🔍 Found duplicate images (visually identical):
#
# Hash: f6d198ee75c51248
#   - train_grid_33771.png
#   - test_grid_8771.png
#
# Hash: b3c30597215505ff
#   - train_grid_33759.png
#   - test_grid_8759.png
#
# Hash: d21d997671ba942c
#   - test_grid_7661.png
#   - train_grid_32661.png

# %%
import os
from PIL import Image
import imagehash
from collections import defaultdict

# ---- CONFIG ----
image_folder = "data/grids/both"   # << CHANGE THIS
valid_ext = {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff"}

# ---- STEP 1: Compute image hashes ----
hash_dict = defaultdict(list)

for filename in os.listdir(image_folder):
    ext = os.path.splitext(filename)[1].lower()
    if ext not in valid_ext:
        continue  # skip non-images

    filepath = os.path.join(image_folder, filename)

    try:
        img = Image.open(filepath)
        img_hash = imagehash.phash(img)  # perceptual hash
        hash_dict[str(img_hash)].append(filename)
    except Exception as e:
        print(f"Error reading {filename}: {e}")

# ---- STEP 2: Print duplicates ----
duplicates = {h: files for h, files in hash_dict.items() if len(files) > 1}

if duplicates:
    print("🔍 Found duplicate images (visually identical):\n")
    for h, files in duplicates.items():
        print(f"Hash: {h}")
        for f in files:
            print(f"  - {f}")
        print()
else:
    print("✅ No duplicate images found.")
# Out:
# 3
